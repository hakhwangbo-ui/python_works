# %%
print(10+ 20)
a = 10
b = 20
c = a+ b
print(c)
# Out:
# 30
# 30

# %%
print("hello, world")
# Out:
# hello, world

# %% [markdown]
# #### 리스트 생성과 관리

# %%
flower = ["벚꽂", "개나리", "진달래"]
print(flower)
print(flower[0])
print(flower[-1])
# Out:
# ['벚꽂', '개나리', '진달래']
# 벚꽂
# 진달래

# %% [markdown]
# #### 딕셔너리 생성과 관리

# %%
user = {
    "name": "우영우",
    "age":31
}
print(user)
print(user["name"])
print(user["age"])  
user["city"] = "서울"
print(user)
# Out:
# {'name': '우영우', 'age': 31}
# 우영우
# 31
# {'name': '우영우', 'age': 31, 'city': '서울'}
